# %%
import pickle
import boto3
import numpy as np
import pandas as pd
from geopy.geocoders import Nominatim
from country_list import countries_for_language
pd.set_option('display.max_rows',100)
import country_converter as coco
import pycountry
import pycountry_convert
import time
import plotly.express as px
import plotly.graph_objects as go
from geopy.geocoders import Nominatim
import gmplot

# %%
counts = pd.read_csv('tweetcounts.csv')

# %%
counts.head()
# Out:
#          date         country  count
# 0  2020-01-21   united states     22
# 1  2020-01-21          canada      2
# 0  2020-01-22   united states   2380
# 1  2020-01-22          canada    256
# 2  2020-01-22  united kingdom    246

# %%
date_range = counts[(counts.date >='2020-01-21')&(counts.date <='2020-02-29')]
gmap = gmplot.GoogleMapPlotter(30, 0, 3)
fig = px.scatter_geo(date_range, color="count", locations='country', locationmode='country names',
                     hover_name="country", size="count",size_max=50,
                     animation_frame="date", center={'lat': 34, 'lon': 9},height=600)
fig.show()
# Out:
# <div>
#
#
#             <div id="aeee555b-2058-4137-89d5-922fa14397d4" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aeee555b-2058-4137-89d5-922fa14397d4")) {
#                     Plotly.newPlot(
#                         'aeee555b-2058-4137-89d5-922fa14397d4',
#                         [{"geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>date=2020-01-21<br>count=%{marker.color}<br>country=%{location}", "hovertext": ["united states", "canada"], "legendgroup": "", "locationmode": "country names", "locations": ["united states", "canada"], "marker": {"color": [22, 2], "coloraxis": "coloraxis", "size": [22, 2], "sizemode": "area", "sizeref": 62.3576}, "name": "", "showlegend": false, "type": "scattergeo"}],
# ...
